# %% [markdown]
# # DRIVE Training

# %% [markdown]
# ## Unet

# %% [markdown]
# ## UNetPlus

# %% [markdown]
# ## Unet3+

# %% [markdown]
# ## AttentionUnet

# %% [markdown]
# ## R2Unet

# %% [markdown]
# ## Onet

# %% [markdown]
# ## Pyramid Attention Unet

# %% [markdown]
# ## CBAMAttUNet

# %% [markdown]
# # Chase Dataset

# %% [markdown]
# ## Unet

# %% [markdown]
# ## UNetPlus

# %% [markdown]
# ## Unet3Plus

# %% [markdown]
# ## AttentionUnet

# %% [markdown]
# ## R2Unet

# %% [markdown]
# ## Onet

# %% [markdown]
# ## Pyramid Attention Unet

# %% [markdown]
# ## CBAMAttUNet

# %% [markdown]
# # STARE

# %% [markdown]
# ## Unet

# %% [markdown]
# ## Unet Plus

# %% [markdown]
# ## Unet3Plus

# %% [markdown]
# ## Attention Unet

# %% [markdown]
# ## R2Unet

# %% [markdown]
# ## Onet

# %% [markdown]
# ## Pyramid Attention Unet

# %% [markdown]
# ## CBAMAttUNet
