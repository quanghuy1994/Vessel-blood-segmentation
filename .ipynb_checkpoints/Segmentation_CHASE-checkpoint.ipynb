# %% [markdown]
# # Unet

# %% [markdown]
# ## Hyper parameter

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
NUM_EPOCHS = 100
NUM_WORKERS = 6
IMAGE_HEIGHT = 512  # 1280 originally
IMAGE_WIDTH = 512  # 1918 originally
PIN_MEMORY = True
LOAD_MODEL = False

# %% [markdown]
# ## Print Params

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = UNet(in_channels=3, out_channels=1).to(device)
summary(model, (3, 512, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 64, 512, 512]           1,728
#        BatchNorm2d-2         [-1, 64, 512, 512]             128
#               ReLU-3         [-1, 64, 512, 512]               0
#             Conv2d-4         [-1, 64, 512, 512]          36,864
#        BatchNorm2d-5         [-1, 64, 512, 512]             128
#               ReLU-6         [-1, 64, 512, 512]               0
#         DoubleConv-7         [-1, 64, 512, 512]               0
#          MaxPool2d-8         [-1, 64, 256, 256]               0
#             Conv2d-9        [-1, 128, 256, 256]          73,728
#       BatchNorm2d-10        [-1, 128, 256, 256]             256
#              ReLU-11        [-1, 128, 256, 256]               0
#            Conv2d-12        [-1, 128, 256, 256]         147,456
#       BatchNorm2d-13        [-1, 128, 256, 256]             256
# ...

# %% [markdown]
# # Unet++

# %% [markdown]
# ## Hyper Parameters

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
NUM_EPOCHS = 100
NUM_WORKERS = 6
IMAGE_HEIGHT = 512  # 1280 originally
IMAGE_WIDTH = 512  # 1918 originally
PIN_MEMORY = True
LOAD_MODEL = False

# %% [markdown]
# ## Print Params

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = UNetplus(in_channels=3, out_channels=1).to(device)
summary(model, (3, 512, 512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1         [-1, 32, 512, 512]             864
#        BatchNorm2d-2         [-1, 32, 512, 512]              64
#               ReLU-3         [-1, 32, 512, 512]               0
#             Conv2d-4         [-1, 32, 512, 512]           9,216
#        BatchNorm2d-5         [-1, 32, 512, 512]              64
#               ReLU-6         [-1, 32, 512, 512]               0
#         DoubleConv-7         [-1, 32, 512, 512]               0
#          MaxPool2d-8         [-1, 32, 256, 256]               0
#             Conv2d-9         [-1, 64, 256, 256]          18,432
#       BatchNorm2d-10         [-1, 64, 256, 256]             128
#              ReLU-11         [-1, 64, 256, 256]               0
#            Conv2d-12         [-1, 64, 256, 256]          36,864
#       BatchNorm2d-13         [-1, 64, 256, 256]             128
# ...

# %% [markdown]
# # Unet3+

# %% [markdown]
# ## Hyper Parameters

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
NUM_EPOCHS = 100
NUM_WORKERS = 6
IMAGE_HEIGHT = 512  # 1280 originally
IMAGE_WIDTH = 512  # 1918 originally
PIN_MEMORY = True
LOAD_MODEL = False

# %% [markdown]
# ## Print Parameters

# %%
model = UNet3Plus()

for name, param in model.named_parameters():
    num_params = param.numel()
    print(f"Parameter: {name}, Size: {param.size()}, Number of Parameters: {num_params}")
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")

print(model)
# Out:
# Parameter: enc1.double_conv.0.weight, Size: torch.Size([64, 3, 3, 3]), Number of Parameters: 1728
# Parameter: enc1.double_conv.0.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: enc1.double_conv.1.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: enc1.double_conv.1.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: enc1.double_conv.3.weight, Size: torch.Size([64, 64, 3, 3]), Number of Parameters: 36864
# Parameter: enc1.double_conv.3.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: enc1.double_conv.4.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: enc1.double_conv.4.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: enc2.double_conv.0.weight, Size: torch.Size([128, 64, 3, 3]), Number of Parameters: 73728
# Parameter: enc2.double_conv.0.bias, Size: torch.Size([128]), Number of Parameters: 128
# ...

# %% [markdown]
# # AttUnet (Attention Unet)

# %% [markdown]
# ## Hyper Parameters

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
NUM_EPOCHS = 100
NUM_WORKERS = 6
IMAGE_HEIGHT = 512  # 1280 originally
IMAGE_WIDTH = 512  # 1918 originally
PIN_MEMORY = True
LOAD_MODEL = False

# %% [markdown]
# ## Attention Unet Model

# %% [markdown]
# ## Print Params

# %%
model = AttU_Net()

for name, param in model.named_parameters():
    num_params = param.numel()
    print(f"Parameter: {name}, Size: {param.size()}, Number of Parameters: {num_params}")
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")

print(model)
# Out:
# Parameter: Conv1.conv.0.weight, Size: torch.Size([64, 3, 3, 3]), Number of Parameters: 1728
# Parameter: Conv1.conv.0.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: Conv1.conv.1.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: Conv1.conv.1.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: Conv1.conv.3.weight, Size: torch.Size([64, 64, 3, 3]), Number of Parameters: 36864
# Parameter: Conv1.conv.3.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: Conv1.conv.4.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: Conv1.conv.4.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: Conv2.conv.0.weight, Size: torch.Size([128, 64, 3, 3]), Number of Parameters: 73728
# Parameter: Conv2.conv.0.bias, Size: torch.Size([128]), Number of Parameters: 128
# Parameter: Conv2.conv.1.weight, Size: torch.Size([128]), Number of Parameters: 128
# ...

# %% [markdown]
# ## Main Function

# %%
main()
# Out:
# 0
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.07it/s]
# Accuracy: 90.74212779169497
# 0.02015043929326885
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  5.58it/s]
# Accuracy: 93.22563171386719
# 0.0
# 1
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.11it/s]
# Accuracy: 92.83526876698369
# 0.006663876637800599
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  5.55it/s]
# Accuracy: 7.173614501953125
# 0.07042410629015869
# 2
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.11it/s]
# Accuracy: 92.88325102432914
# 0.01142950614212122
# 100%|█████████████████████████████████████████████| 3/3 [00:00<00:00,  5.63it/s]
# Accuracy: 67.94326782226562
# 0.11378879786722461
# 3
# 100%|███████████████████████████████████████████| 12/12 [00:02<00:00,  5.16it/s]
# Accuracy: 93.25103759765625
# 0.09212686966765431
# ...

# %% [markdown]
# # R2U_Net

# %% [markdown]
# ## Hyper Parameters

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
NUM_EPOCHS = 100
NUM_WORKERS = 6
IMAGE_HEIGHT = 512  # 1280 originally
IMAGE_WIDTH = 512  # 1918 originally
PIN_MEMORY = True
LOAD_MODEL = False

# %% [markdown]
# ## Print Params

# %%
model = R2UNet()

for name, param in model.named_parameters():
    num_params = param.numel()
    print(f"Parameter: {name}, Size: {param.size()}, Number of Parameters: {num_params}")
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")

print(model)
# Out:
# Parameter: RRCNN1.RCNN.0.conv.0.weight, Size: torch.Size([64, 64, 3, 3]), Number of Parameters: 36864
# Parameter: RRCNN1.RCNN.0.conv.0.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: RRCNN1.RCNN.0.conv.1.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: RRCNN1.RCNN.0.conv.1.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: RRCNN1.RCNN.1.conv.0.weight, Size: torch.Size([64, 64, 3, 3]), Number of Parameters: 36864
# Parameter: RRCNN1.RCNN.1.conv.0.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: RRCNN1.RCNN.1.conv.1.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: RRCNN1.RCNN.1.conv.1.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: RRCNN1.Conv_1x1.weight, Size: torch.Size([64, 3, 1, 1]), Number of Parameters: 192
# Parameter: RRCNN1.Conv_1x1.bias, Size: torch.Size([64]), Number of Parameters: 64
# ...

# %% [markdown]
# # Patt Unet

# %% [markdown]
# ## Hyper Parameter

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
NUM_EPOCHS = 100
NUM_WORKERS = 6
IMAGE_HEIGHT = 512  # 1280 originally
IMAGE_WIDTH = 512  # 1918 originally
PIN_MEMORY = True
LOAD_MODEL = False

# %% [markdown]
# ## Print Params

# %%
model = PAttUNet()

for name, param in model.named_parameters():
    num_params = param.numel()
    print(f"Parameter: {name}, Size: {param.size()}, Number of Parameters: {num_params}")
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")

print(model)
# Out:
# Parameter: conv0_0.conv.0.weight, Size: torch.Size([32, 3, 3, 3]), Number of Parameters: 864
# Parameter: conv0_0.conv.1.weight, Size: torch.Size([32]), Number of Parameters: 32
# Parameter: conv0_0.conv.1.bias, Size: torch.Size([32]), Number of Parameters: 32
# Parameter: conv0_0.conv.3.weight, Size: torch.Size([32, 32, 3, 3]), Number of Parameters: 9216
# Parameter: conv0_0.conv.4.weight, Size: torch.Size([32]), Number of Parameters: 32
# Parameter: conv0_0.conv.4.bias, Size: torch.Size([32]), Number of Parameters: 32
# Parameter: conv1_0.conv.0.weight, Size: torch.Size([64, 64, 3, 3]), Number of Parameters: 36864
# Parameter: conv1_0.conv.1.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: conv1_0.conv.1.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: conv1_0.conv.3.weight, Size: torch.Size([64, 64, 3, 3]), Number of Parameters: 36864
# Parameter: conv1_0.conv.4.weight, Size: torch.Size([64]), Number of Parameters: 64
# ...

# %% [markdown]
# # ONET

# %% [markdown]
# ## Hyper Parameter

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
NUM_EPOCHS = 100
NUM_WORKERS = 6
IMAGE_HEIGHT = 512  # 1280 originally
IMAGE_WIDTH = 512  # 1918 originally
PIN_MEMORY = True
LOAD_MODEL = False

# %% [markdown]
# ## Print Params

# %%
model = ONET()

for name, param in model.named_parameters():
    num_params = param.numel()
    print(f"Parameter: {name}, Size: {param.size()}, Number of Parameters: {num_params}")
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")

print(model)
# Out:
# Parameter: top_en.0.conv1.weight, Size: torch.Size([64, 3, 3, 3]), Number of Parameters: 1728
# Parameter: top_en.0.bn1.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: top_en.0.bn1.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: top_en.0.conv2.weight, Size: torch.Size([64, 64, 3, 3]), Number of Parameters: 36864
# Parameter: top_en.0.bn2.weight, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: top_en.0.bn2.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: top_en.1.weight, Size: torch.Size([64, 64, 2, 2]), Number of Parameters: 16384
# Parameter: top_en.1.bias, Size: torch.Size([64]), Number of Parameters: 64
# Parameter: top_en.2.conv1.weight, Size: torch.Size([32, 64, 3, 3]), Number of Parameters: 18432
# Parameter: top_en.2.bn1.weight, Size: torch.Size([32]), Number of Parameters: 32
# Parameter: top_en.2.bn1.bias, Size: torch.Size([32]), Number of Parameters: 32
# ...

# %% [markdown]
# # CBAMAttU_Net

# %% [markdown]
# ## Hyper Parameters

# %%
LEARNING_RATE = 1e-4
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
BATCH_SIZE = 2
NUM_EPOCHS = 100
NUM_WORKERS = 6
IMAGE_HEIGHT = 512  # 1280 originally
IMAGE_WIDTH = 512  # 1918 originally
PIN_MEMORY = True
LOAD_MODEL = False

# %% [markdown]
# ## Print Params

# %%
model = CBAMAttU_Net()

for name, param in model.named_parameters():
    num_params = param.numel()
    print(f"{name} ")
total_params = sum(p.numel() for p in model.parameters())
print(f"Total number of parameters: {total_params}")

print(model)
# Out:
# CBAM_block1.CBAM.0.channel_attention.fc1.weight
# CBAM_block1.CBAM.0.channel_attention.fc1.bias
# CBAM_block1.CBAM.0.channel_attention.fc2.weight
# CBAM_block1.CBAM.0.channel_attention.fc2.bias
# CBAM_block1.CBAM.0.spatial_attention.conv.weight
# CBAM_block1.CBAM.0.spatial_attention.conv.bias
# CBAM_block1.CBAM.1.channel_attention.fc1.weight
# CBAM_block1.CBAM.1.channel_attention.fc1.bias
# CBAM_block1.CBAM.1.channel_attention.fc2.weight
# CBAM_block1.CBAM.1.channel_attention.fc2.bias
# CBAM_block1.CBAM.1.spatial_attention.conv.weight
# CBAM_block1.CBAM.1.spatial_attention.conv.bias
# CBAM_block1.Conv_1x1.weight
# CBAM_block1.Conv_1x1.bias
# CBAM_block2.CBAM.0.channel_attention.fc1.weight
# CBAM_block2.CBAM.0.channel_attention.fc1.bias
# CBAM_block2.CBAM.0.channel_attention.fc2.weight
# CBAM_block2.CBAM.0.channel_attention.fc2.bias
# CBAM_block2.CBAM.0.spatial_attention.conv.weight
# CBAM_block2.CBAM.0.spatial_attention.conv.bias
# CBAM_block2.CBAM.1.channel_attention.fc1.weight
# ...
